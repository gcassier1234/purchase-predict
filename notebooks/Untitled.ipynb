# %%
# %run_viz
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <IPython.core.display.HTML object>

# %%
dir(catalog)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     '__abstractmethods__',
#     '__annotations__',
#     '__class__',
#     '__class_getitem__',
#     '__contains__',
#     '__delattr__',
#     '__dict__',
#     '__dir__',
#     '__doc__',
#     '__eq__',
#     '__firstlineno__',
#     '__format__',
#     '__ge__',
#     '__getattribute__',
#     '__getitem__',
#     '__getstate__',
#     '__gt__',
#     '__hash__',
#     '__init__',
#     '__init_subclass__',
#     '__iter__',
#     '__le__',
#     '__len__',
#     '__lt__',
#     '__module__',
#     '__ne__',
#     '__new__',
#     '__non_callable_proto_members__',
#     '__orig_bases__',
#     '__parameters__',
#     '__protocol_attrs__',
#     '__reduce__',
#     '__reduce_ex__',
#     '__repr__',
#     '__setattr__',
#     '__setitem__',
#     '__sizeof__',
#     '__slots__',
#     '__static_attributes__',
#     '__str__',
#     '__subclasshook__',
#     '__weakref__',
#     '_abc_impl',
#     '_add_from_config',
#     '_config_resolver',
#     '_datasets',
#     '_ipython_key_completions_',
#     '_is_protocol',
#     '_is_runtime_protocol',
#     '_lazy_datasets',
#     '_load_versions',
#     '_logger',
#     '_save_version',
#     '_use_rich_markup',
#     '_validate_dataset_config',
#     '_validate_versions',
#     'config_resolver',
#     'confirm',
#     'default_runtime_patterns',
#     'describe_datasets',
#     'exists',
#     'filter',
#     'from_config',
#     'get',
#     'get_type',
#     'items',
#     'keys',
#     'list_patterns',
#     'load',
#     'release',
#     'resolve_patterns',
#     'save',
#     'to_config',
#     'values'
# ]

# %%
catalog.items
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <bound method DataCatalog.items of 'primary': kedro_datasets.pandas.csv_dataset.CSVDataset
# 'dataset': kedro_datasets.pandas.csv_dataset.CSVDataset
# 'X_train': kedro_datasets.pandas.csv_dataset.CSVDataset
# 'y_train': kedro_datasets.pandas.csv_dataset.CSVDataset
# 'X_test': kedro_datasets.pandas.csv_dataset.CSVDataset
# 'y_test': kedro_datasets.pandas.csv_dataset.CSVDataset
# 'parameters': kedro.io.memory_dataset.MemoryDataset(data='<dict>')
# 'params:test_ratio': kedro.io.memory_dataset.MemoryDataset(data='<float>')>

# %%
 pri = catalog.load("primary")
# Out:
# [01/28/26 18:23:47] INFO     Loading data from primary (CSVDataset)...                         ]8;id=743537;file://C:\Users\gcass\miniconda3\envs\purchase\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=670288;file://C:\Users\gcass\miniconda3\envs\purchase\Lib\site-packages\kedro\io\data_catalog.py#1048\1048]8;;\

# %%
pri.columns
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Index(['product_id', 'brand', 'price', 'user_id', 'user_session', 'purchased',
#        'num_views_session', 'num_views_product', 'category', 'sub_category',
#        'hour', 'minute', 'weekday', 'duration', 'num_prev_sessions',
#        'num_prev_product_views'],
#       dtype='str')

# %%
pri['brand'].value_counts()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# brand
# samsung    5580
# apple      5176
# xiaomi     2194
# huawei      907
# lucente     321
#            ...
# asics         1
# wess          1
# cezaris       1
# dox           1
# rush          1
# Name: count, Length: 679, dtype: int64

# %%
import pandas as pd

from typing import Dict, Any

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

def encode_features(dataset: pd.DataFrame) -> pd.DataFrame:
    """
    Encode features of data file.
    """
    features = dataset.drop(["user_id", "user_session"], axis=1).copy()

    encoders = []
    for label in ["category", "sub_category", "brand"]:
        features[label] = features[label].astype(str)
        features.loc[features[label] == "nan", label] = "unknown"
        encoder = LabelEncoder()
        features.loc[:, label] = encoder.fit_transform(features.loc[:, label]).astype(str)
        encoders.append((label, encoder))

# %%
encode_features(pri)
